# %%
import pandas as pd

# %% [markdown]
# # 1. Data Example

# %%
# Eating, exercise habbit and their body shape
df = pd.DataFrame(columns=['calory', 'breakfast', 'lunch', 'dinner', 'exercise', 'body_shape'])

# %%
df.loc[0] = [1200, 1, 0, 0, 2, 'Skinny']
df.loc[1] = [2800, 1, 1, 1, 1, 'Normal']
df.loc[2] = [3500, 2, 2, 1, 0, 'Fat']
df.loc[3] = [1400, 0, 1, 0, 3, 'Skinny']
df.loc[4] = [5000, 2, 2, 2, 0, 'Fat']
df.loc[5] = [1300, 0, 0, 1, 2, 'Skinny']
df.loc[6] = [3000, 1, 0, 1, 1, 'Normal']
df.loc[7] = [4000, 2, 2, 2, 0, 'Fat']
df.loc[8] = [2600, 0, 2, 0, 0, 'Normal']
df.loc[9] = [3000, 1, 2, 1, 1, 'Fat']

# %%
df.head(10)
# Out:
#    calory  breakfast  lunch  dinner  exercise body_shape
# 0    1200          1      0       0         2     Skinny
# 1    2800          1      1       1         1     Normal
# 2    3500          2      2       1         0        Fat
# 3    1400          0      1       0         3     Skinny
# 4    5000          2      2       2         0        Fat
# 5    1300          0      0       1         2     Skinny
# 6    3000          1      0       1         1     Normal
# 7    4000          2      2       2         0        Fat
# 8    2600          0      2       0         0     Normal
# 9    3000          1      2       1         1        Fat

# %% [markdown]
# # 2. Split feature vectors and labels

# %%
# X is feature vectors
X = df[['calory', 'breakfast', 'lunch', 'dinner', 'exercise']]

# %%
X.head(9)
# Out:
#    calory  breakfast  lunch  dinner  exercise
# 0    1200          1      0       0         2
# 1    2800          1      1       1         1
# 2    3500          2      2       1         0
# 3    1400          0      1       0         3
# 4    5000          2      2       2         0
# 5    1300          0      0       1         2
# 6    3000          1      0       1         1
# 7    4000          2      2       2         0
# 8    2600          0      2       0         0

# %%
# Y is labels
Y = df[['body_shape']]

# %%
Y.head(10)
# Out:
#   body_shape
# 0     Skinny
# 1     Normal
# 2        Fat
# 3     Skinny
# 4        Fat
# 5     Skinny
# 6     Normal
# 7        Fat
# 8     Normal
# 9        Fat

# %% [markdown]
# # 3. rescaling feature vectors to all have the same scale

# %%
from sklearn.preprocessing import StandardScaler
x_std = StandardScaler().fit_transform(X)

# %%
x_std
# Out:
# array([[-1.35205803,  0.        , -1.3764944 , -1.28571429,  1.        ],
#        [ 0.01711466,  0.        , -0.22941573,  0.14285714,  0.        ],
#        [ 0.61612771,  1.29099445,  0.91766294,  0.14285714, -1.        ],
#        [-1.18091145, -1.29099445, -0.22941573, -1.28571429,  2.        ],
#        [ 1.89972711,  1.29099445,  0.91766294,  1.57142857, -1.        ],
#        [-1.26648474, -1.29099445, -1.3764944 ,  0.14285714,  1.        ],
#        [ 0.18826125,  0.        , -1.3764944 ,  0.14285714,  0.        ],
#        [ 1.04399418,  1.29099445,  0.91766294,  1.57142857, -1.        ],
#        [-0.15403193, -1.29099445,  0.91766294, -1.28571429, -1.        ],
#        [ 0.18826125,  0.        ,  0.91766294,  0.14285714,  0.        ]])

# %% [markdown]
# # 4. Covariance Matrix of features

# %%
import numpy as np

# %%
# features are columns from x_std
features = x_std.T
covariance_matrix = np.cov(features)
print(covariance_matrix)
# Out:
# [[ 1.11111111  0.88379717  0.76782385  0.89376551 -0.93179808]
#  [ 0.88379717  1.11111111  0.49362406  0.81967902 -0.71721914]
#  [ 0.76782385  0.49362406  1.11111111  0.40056715 -0.76471911]
#  [ 0.89376551  0.81967902  0.40056715  1.11111111 -0.63492063]
#  [-0.93179808 -0.71721914 -0.76471911 -0.63492063  1.11111111]]

# %% [markdown]
# # 5. Eigen Vectors and Eigen Values from Covariance Matrix

# %%
eig_vals, eig_vecs = np.linalg.eig(covariance_matrix)

# %%
print('Eigenvectors \n%s' %eig_vecs)
# Out:
# Eigenvectors
# [[-0.508005   -0.0169937  -0.84711404  0.11637853  0.10244985]
#  [-0.44660335 -0.36890361  0.12808055 -0.63112016 -0.49973822]
#  [-0.38377913  0.70804084  0.20681005 -0.40305226  0.38232213]
#  [-0.42845209 -0.53194699  0.3694462   0.22228235  0.58954327]
#  [ 0.46002038 -0.2816592  -0.29450345 -0.61341895  0.49601841]]

# %%
print('\nEigenvalues \n%s' %eig_vals)
# Out:
# Eigenvalues
# [4.0657343  0.8387565  0.07629538 0.27758568 0.2971837 ]

# %%
# We reduce dimension to 1 dimension, since 1 eigenvector has 73% (enough) variances
eig_vals[0] / sum(eig_vals)
# Out:
# np.float64(0.7318321731427544)

# %%
# We reduce dimension to 2 dimension, since 2 eigenvector has  88% variances
(eig_vals[0] + eig_vals[1]) / sum(eig_vals)
# Out:
# np.float64(0.8828083437099054)

# %% [markdown]
# # 6. Project data point onto selected Eigen Vector

# %% [markdown]
# Objetivo: Reducir la dimensionalidad de los datos proyectándolos en el primer autovector (el que captura la mayor cantidad de varianza).
#
# Con esta proyección, podemos representar los datos en un espacio de menor dimensión mientras retenemos la mayor parte de la información.

# %%
projected_X = x_std.dot(eig_vecs.T[0])

# %% [markdown]
# Esta línea proyecta los datos estandarizado (x_std)s sobre el primer autovector.
#
# El resultado es un nuevo conjunto de datos, pero en una dimensión reducida. En este caso, estamos reduciendo el conjunto de datos a una sola dimensión.
# En términos prácticos, el primer autovector representa la dirección en la que la mayor cantidad de información (varianza) de los datos es capturada.
#
# Entonces, al proyectar los datos en esa dirección, obtenemos una versión "condensada" de los datos con menor dimensionalidad pero que conserva la mayor varianza posible.

# %%
projected_X
# Out:
# array([ 2.22600943,  0.0181432 , -1.76296611,  2.73542407, -3.02711544,
#         2.14702579,  0.37142473, -2.59239883,  0.39347815, -0.50902498])

# %%
result = pd.DataFrame(projected_X, columns=['PC1'])

# %%
result
# Out:
#         PC1
# 0  2.226009
# 1  0.018143
# 2 -1.762966
# 3  2.735424
# 4 -3.027115
# 5  2.147026
# 6  0.371425
# 7 -2.592399
# 8  0.393478
# 9 -0.509025

# %%
result = pd.DataFrame(projected_X, columns=['PC1'])
result['y-axis'] = 0.0
result['label'] = Y

# %%
result.head(10)
# Out:
#         PC1  y-axis   label
# 0  2.226009     0.0  Skinny
# 1  0.018143     0.0  Normal
# 2 -1.762966     0.0     Fat
# 3  2.735424     0.0  Skinny
# 4 -3.027115     0.0     Fat
# 5  2.147026     0.0  Skinny
# 6  0.371425     0.0  Normal
# 7 -2.592399     0.0     Fat
# 8  0.393478     0.0  Normal
# 9 -0.509025     0.0     Fat

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.lmplot(data=result,x='PC1', y='y-axis', hue="label", fit_reg=False,  # x-axis, y-axis, data, no line
           scatter_kws={"s": 50} # marker size
           ) # color

# title
plt.title('PCA result')
# Out:
# Text(0.5, 1.0, 'PCA result')

# %% [markdown]
# # bonus - scikit-learn PCA

# %%
from sklearn import decomposition

# Fit PCA without reducing components yet
pca = decomposition.PCA()
pca.fit(x_std)

# Eigenvalues (variance explained by each component)
eigenvalues = pca.explained_variance_

# Explained variance ratio (fraction of total variance each PC explains)
explained_variance_ratio = pca.explained_variance_ratio_

# Optional: cumulative explained variance (to see how many PCs explain X% variance)
cumulative_variance = explained_variance_ratio.cumsum()

print("Eigenvalues:", eigenvalues)
print("Explained Variance Ratio:", explained_variance_ratio)
print("Cumulative Variance:", cumulative_variance)
# Out:
# Eigenvalues: [4.0657343  0.8387565  0.2971837  0.27758568 0.07629538]
# Explained Variance Ratio: [0.73183217 0.15097617 0.05349307 0.04996542 0.01373317]
# Cumulative Variance: [0.73183217 0.88280834 0.93630141 0.98626683 1.        ]

# %% [markdown]
# 1 Principal Component

# %%
#Once we decide on the number of principal components we run it again
pca = decomposition.PCA(n_components=1)
sklearn_pca_x = pca.fit_transform(x_std)

# %%
sklearn_result = pd.DataFrame(sklearn_pca_x, columns=['PC1'])
sklearn_result['y-axis'] = 0.0
sklearn_result['label'] = Y

# %%
sklearn_result
# Out:
#         PC1  y-axis   label
# 0 -2.226009     0.0  Skinny
# 1 -0.018143     0.0  Normal
# 2  1.762966     0.0     Fat
# 3 -2.735424     0.0  Skinny
# 4  3.027115     0.0     Fat
# 5 -2.147026     0.0  Skinny
# 6 -0.371425     0.0  Normal
# 7  2.592399     0.0     Fat
# 8 -0.393478     0.0  Normal
# 9  0.509025     0.0     Fat

# %%
sns.lmplot(data=sklearn_result,x='PC1', y='y-axis', hue="label", fit_reg=False,  # x-axis, y-axis, data, no line
           scatter_kws={"s": 50} # marker size
           ) # color

# title
plt.title('PCA result')
# Out:
# Text(0.5, 1.0, 'PCA result')

# %% [markdown]
# 2 Principal Components

# %%
#Once we decide on the number of principal components we run it again
pca = decomposition.PCA(n_components=2)
sklearn_pca_x = pca.fit_transform(x_std)

sklearn_result = pd.DataFrame(sklearn_pca_x, columns=['PC1', 'PC2'])
sklearn_result['label'] = Y

sklearn_result
# Out:
#         PC1       PC2   label
# 0 -2.226009 -0.549365  Skinny
# 1 -0.018143 -0.238719  Normal
# 2  1.762966  0.368687     Fat
# 3 -2.735424  0.454498  Skinny
# 4  3.027115 -0.413051     Fat
# 5 -2.147026 -0.834491  Skinny
# 6 -0.371425 -1.053806  Normal
# 7  2.592399 -0.398508     Fat
# 8 -0.393478  2.094204  Normal
# 9  0.509025  0.570551     Fat

# %%
sns.lmplot(data=sklearn_result,x='PC1', y='PC2', hue="label", fit_reg=False,
           scatter_kws={"s": 50}
           )

# title
plt.title('PCA result')
# Out:
# Text(0.5, 1.0, 'PCA result')
